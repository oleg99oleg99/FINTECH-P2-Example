# %% [markdown]
# <a href="https://colab.research.google.com/github/oleg99oleg99/FINTECH-P2-Example/blob/main/FINA4075_P2_StrategyLab_executed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # FINA 4075/5075 — Project 2 · The Strategy Lab — pre-registration notebook (Fall 2026)
#
# **Repo:** FINTECH-P2-Example · **Track 1:** intermediate momentum, months t−12 … t−7 (top 20 of 200, equal weights, 10 bp per side) · **Track 2:** frozen prompt on Claude Fable 5.1 Max · **Pre-registration commit:** Sun 9/20/2026 (hash quoted in `monitoring_log.md` and the final report)
#
# **Before running anything:** File → **Save a copy in Drive**, then Runtime → Change runtime type → **Runtime version 2026.07** (Rule 0). Cells 1–4 are the Project 0 template. Run top to bottom; finish with **Runtime → Restart session and run all** (Rule 6) before you save the notebook to GitHub.
#
# **Code Rule:** after the 9/20 commit the strategy code (`strategy.py`, written by Cell 6) is read-only. At each checkpoint you point Cell 2 at the new dated extension file and rerun — nothing else changes.

# %%
# Cell 1 — mount Drive (Rule 1)
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Cell 2 — course folder and the packet files (Rule 1 / Rule 4: analysis reads the dated snapshot)
import os
P2 = "/content/drive/MyDrive/FINA4075/P2"
OUT = P2 + "/outputs"
os.makedirs(OUT, exist_ok=True)

PANEL_FILE = P2 + "/panel_returns_2026-08-31.csv"      # at checkpoints: the dated extension file (e.g. ..._2026-09-30.csv)
TICKER_FILE = P2 + "/P2_ticker_list_2026-08-31.csv"
PANEL_SHA256 = "c9d3340eba3a3301a63bb788c87f1d6e9e55de58a3fec16b12a34b313cac076b"   # from the Data Dictionary
print("Folder ready:", P2)
# Out:
# Folder ready: /content/drive/MyDrive/FINA4075/P2

# %%
# Cell 3 — pinned setup (Rule 2). Official pinned line from D2L; the P2 analysis itself needs only pandas, numpy and
# matplotlib, which the pinned runtime already provides — never reinstall those.
# %pip install -q yfinance==0.2.66

# %%
# Cell 4 — environment stamp (Rule 0)
import sys, pandas as pd, numpy as np, matplotlib, yfinance as yf
print(sys.version)
print("pandas", pd.__version__, "| numpy", np.__version__,
      "| matplotlib", matplotlib.__version__, "| yfinance", yf.__version__)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]
# pandas 2.2.2 | numpy 2.0.2 | matplotlib 3.10.0 | yfinance 0.2.66

# %% [markdown]
# ## Step 1 — load the packet and verify the hash
# The SHA-256 of the panel file must equal the value published in the Data Dictionary. If it does not, the file was edited or re-saved: download it again from D2L.

# %%
# Cell 5 — hash check and load
import hashlib
sha = hashlib.sha256(open(PANEL_FILE, "rb").read()).hexdigest()
print("SHA-256:", sha)
assert sha == PANEL_SHA256, "panel file does not match the Data Dictionary hash"

panel = pd.read_csv(PANEL_FILE, index_col=0, parse_dates=True)
info = pd.read_csv(TICKER_FILE).set_index("Ticker")
print("panel shape:", panel.shape, "| first month:", panel.index[0].date(), "| last month:", panel.index[-1].date())
print("missing values:", int(panel.isna().sum().sum()), "| tickers match the company list:", list(panel.columns) == list(info.index))
# Out:
# SHA-256: c9d3340eba3a3301a63bb788c87f1d6e9e55de58a3fec16b12a34b313cac076b
# panel shape: (92, 200) | first month: 2019-01-31 | last month: 2026-08-31
# missing values: 0 | tickers match the company list: True

# %% [markdown]
# ## Steps 4 and 7 — the locked rule
# The rule lives in one plain-text file, `strategy.py`, so the grader can diff it against the 9/20 commit. Cell 6 writes the file into the P2 folder; Cell 7 imports it. `strategy_rules.md` governs if the two ever disagree.

# %%
# %%writefile /content/drive/MyDrive/FINA4075/P2/strategy.py
"""
strategy.py — LOCKED STRATEGY CODE (Track 1)   ·   FINTECH-P2-Example   ·   FINA 4075/5075, Fall 2026

Rule (see strategy_rules.md, which governs if the two ever disagree):
  Intermediate momentum, months t-12 through t-7.  For the portfolio held in month t, rank the 200
  stocks by their compounded total return over the SIX monthly returns t-12, t-11, ..., t-7
  (the most recent six months, t-6 .. t-1, are skipped entirely).  Hold the top 20, equal weights,
  rebalanced at every month-end from data through the prior month-end only.  10 bp per side.

CODE RULE: this file is read-only after the 9/20/2026 pre-registration commit.  At each checkpoint
the panel is extended by one month and this code is rerun unchanged.
"""
import numpy as np
import pandas as pd

PER_SIDE = 0.0010        # transaction cost, 10 basis points per side
N_HOLD = 20              # holding count (the top decile of the 200-stock panel)
WINDOW_START = 12        # window starts WINDOW_START months before month t  (t-12)
WINDOW_END = 7           # window ends   WINDOW_END   months before month t  (t-7), inclusive
FIRST_TRADEABLE = WINDOW_START   # the first month t whose window exists is row 12 (January 2020)


def load_panel(panel_path, ticker_path):
    """Read the course packet.  Returns (rets, dates, tickers, info).

    rets    : numpy array, T x N, simple monthly total returns (row 0 = January 2019)
    dates   : the month-end dates of the rows
    tickers : list of the N ticker symbols, in the column order of the panel
    info    : the company list (ticker, company, sector, ...) indexed by ticker
    """
    panel = pd.read_csv(panel_path, index_col=0, parse_dates=True)
    info = pd.read_csv(ticker_path).set_index("Ticker")
    tickers = list(panel.columns)
    assert list(info.index) == tickers, "ticker list and panel columns differ"
    assert not panel.isna().any().any(), "panel has missing values"
    return panel.to_numpy(), panel.index, tickers, info


def signal(t, rets):
    """Compounded return over rows t-12 .. t-7 inclusive (six monthly returns).

    Python slicing excludes the stop index, so rows t-12 .. t-7 are rets[t-12 : t-6].
    """
    window = rets[t - WINDOW_START : t - WINDOW_END + 1]
    assert window.shape[0] == WINDOW_START - WINDOW_END + 1 == 6
    return np.prod(1 + window, axis=0) - 1


def select_holdings(t, rets, tickers):
    """The 20 stocks held during month t: highest signal first; ties broken by alphabetical ticker.

    A stock with any missing return in its t-12..t-7 window is ineligible for month t (rules: MISSING
    DATA). The released panel has no gaps, so every stock is eligible in-sample; this guard governs
    the live window, where an extension file could carry a delisted name's partial history.
    """
    window = rets[t - WINDOW_START : t - WINDOW_END + 1]
    eligible = ~np.isnan(window).any(axis=0)
    sig = signal(t, rets)
    cand = [i for i in range(len(tickers)) if eligible[i]]
    order = sorted(cand, key=lambda i: (-sig[i], tickers[i]))
    return set(order[:N_HOLD])


def run_track(select_fn, rets, t0, t1, per_side=PER_SIDE):
    """Paper-trade a selection rule from month t0 to month t1 (row indices, inclusive).

    Course conventions: equal weights; one-way turnover = names replaced / 20 (the first month
    counts as a full purchase); monthly cost = 2 x per_side x turnover; growth path starts at 1.0.
    Returns (values, turnovers, holdings) with len(values) == months + 1.
    """
    prev, vals, turns, holdings = set(), [1.0], [], []
    for t in range(t0, t1 + 1):
        hold = select_fn(t, rets)
        turn = 1.0 if not prev else len(hold - prev) / N_HOLD
        gross = rets[t, sorted(hold)].mean()
        vals.append(vals[-1] * (1 + gross - 2 * per_side * turn))
        prev = hold
        turns.append(turn)
        holdings.append(hold)
    return np.array(vals), np.array(turns), holdings


def bench(rets, t0, t1):
    """Equal-weighted average of all 200 stocks, rebalanced monthly, no costs."""
    vals = [1.0]
    for t in range(t0, t1 + 1):
        vals.append(vals[-1] * (1 + rets[t].mean()))
    return np.array(vals)


def stats(vals, turns=None):
    """CAGR, annualized volatility, Sharpe (rf = 0), maximum drawdown, annual one-way turnover."""
    months = len(vals) - 1
    monthly = vals[1:] / vals[:-1] - 1
    cagr = vals[-1] ** (12 / months) - 1
    vol = monthly.std(ddof=1) * np.sqrt(12)
    maxdd = (vals / np.maximum.accumulate(vals) - 1).min()
    out = {"CAGR": cagr, "Annualized volatility": vol, "Sharpe (rf = 0)": cagr / vol,
           "Maximum drawdown": maxdd, "Growth of $10,000": 10000 * vals[-1]}
    if turns is not None:
        out["Annual one-way turnover"] = turns.mean() * 12
        out["Cost drag per year"] = 2 * PER_SIDE * turns.mean() * 12
    return out
# Out:
# Overwriting /content/drive/MyDrive/FINA4075/P2/strategy.py

# %%
# Cell 7 — import the locked code from Drive and bind the rule to this panel
import importlib, sys
if P2 not in sys.path:
    sys.path.insert(0, P2)
import strategy as S
importlib.reload(S)

rets, dates, tickers, info = S.load_panel(PANEL_FILE, TICKER_FILE)
def rule(t, rets):
    return S.select_holdings(t, rets, tickers)
print("rows (months):", len(dates), "| first tradeable row:", S.FIRST_TRADEABLE, "=", dates[S.FIRST_TRADEABLE].date())
# Out:
# rows (months): 92 | first tradeable row: 12 = 2020-01-31

# %% [markdown]
# ## Step 7 — in-sample backtest, January 2020 – August 2026 (80 months)
# Pre-live sample only. Net of 10 bp per side; the benchmark is the equal-weighted panel with no costs; rf = 0 for the Sharpe ratio.

# %%
# Cell 8 — run both tracks' in-sample paths and the stats table
t0, t1 = S.FIRST_TRADEABLE, len(dates) - 1                 # row 12 (Jan 2020) .. row 91 (Aug 2026)
vals, turns, holdings = S.run_track(rule, rets, t0, t1)
bvals = S.bench(rets, t0, t1)

strat_stats, bench_stats = S.stats(vals, turns), S.stats(bvals)
rows = ["CAGR", "Annualized volatility", "Sharpe (rf = 0)", "Maximum drawdown", "Annual one-way turnover", "Cost drag per year", "Growth of $10,000"]
table = pd.DataFrame({"Intermediate momentum (net)": [strat_stats.get(r) for r in rows],
                      "EW benchmark (no costs)": [bench_stats.get(r) for r in rows]}, index=rows)
def fmt(v, r):
    if v is None or (isinstance(v, float) and np.isnan(v)): return "—"
    if r == "Growth of $10,000": return f"${v:,.0f}"
    if r == "Sharpe (rf = 0)": return f"{v:.2f}"
    return f"{v*100:.1f}%"
shown = pd.DataFrame({c: [fmt(table.loc[r, c], r) for r in rows] for c in table.columns}, index=rows)
print(f"In-sample window: {dates[t0].date()} to {dates[t1].date()} ({t1 - t0 + 1} months)")
print(shown.to_string())
table.to_csv(OUT + "/insample_stats_2026-08-31.csv")
# Out:
# In-sample window: 2020-01-31 to 2026-08-31 (80 months)
#                         Intermediate momentum (net) EW benchmark (no costs)
# CAGR                                          20.3%                   15.4%
# Annualized volatility                         23.8%                   21.4%
# Sharpe (rf = 0)                                0.85                    0.72
# Maximum drawdown                             -21.5%                  -31.7%
# Annual one-way turnover                      441.7%                       —
# Cost drag per year                             0.9%                       —
# Growth of $10,000                           $34,286                 $25,947

# %%
# Cell 9 — growth-of-$10,000 exhibit (saved to Drive, Rule 7)
import matplotlib.pyplot as plt
x = dates[t0 - 1 : t1 + 1]                                 # month-ends; the path starts one month before the first holding month
fig, ax = plt.subplots(figsize=(9, 4.8))
ax.plot(x, 10000 * vals, label="Track 1: intermediate momentum (t−12…t−7), top 20 EW, net of 10 bp/side", lw=1.8)
ax.plot(x, 10000 * bvals, label="Equal-weighted panel (200 stocks), no costs", lw=1.8)
ax.axhline(10000, ls="--", lw=0.8, color="gray")
ax.set_title("Growth of $10,000 — in-sample, January 2020 to August 2026 (80 months)")
ax.set_ylabel("Portfolio value ($)")
ax.legend(loc="upper left", fontsize=9)
ax.text(0.01, -0.16, "Source: panel_returns_2026-08-31.csv (Yahoo Finance, dividends reinvested). Panel has survivorship and selection bias; rf = 0 for Sharpe.",
        transform=ax.transAxes, fontsize=7.5, color="gray")
plt.tight_layout()
fig.savefig(OUT + "/insample_growth_2026-08-31.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## Step 7 — hand verification of one month (August 2026)
# Pick three of the twenty holdings, look their August 2026 returns up in the CSV, and confirm the arithmetic below: gross = the simple average of the twenty returns; cost = 2 × 0.0010 × turnover; net = gross − cost.

# %%
# Cell 10 — one month by hand: the last in-sample month, August 2026 (row 91)
t = t1
hold_now, hold_prev = holdings[t - t0], holdings[t - t0 - 1]
names = sorted(tickers[i] for i in hold_now)
r_month = pd.Series({tickers[i]: rets[t, i] for i in hold_now}).sort_index()
gross = r_month.mean()
turn = len(hold_now - hold_prev) / S.N_HOLD
cost = 2 * S.PER_SIDE * turn
print(f"Month scored: {dates[t].date()} | signal window: {dates[t-12].date()} .. {dates[t-7].date()}")
print("Holdings (20):", ", ".join(names))
print((100 * r_month).round(2).to_string())
print(f"\ngross = mean of the 20 returns = {gross:.6f} ({gross*100:.3f}%)")
print(f"turnover = names replaced / 20 = {len(hold_now - hold_prev)} / 20 = {turn:.2f}  ->  cost = 2 x 0.0010 x {turn:.2f} = {cost:.6f}")
print(f"net = {gross - cost:.6f} ({(gross - cost)*100:.3f}%)  ->  on $10,000: ${10000 * (gross - cost):,.2f}")
print("Three holdings to check against the CSV by hand:", ", ".join(f"{n} {rets[t, tickers.index(n)]*100:+.3f}%" for n in names[:3]))
print("Engine's own value for this month:", f"{vals[t - t0 + 1] / vals[t - t0] - 1:.6f}", "(must equal net above)")
# Out:
# Month scored: 2026-08-31 | signal window: 2025-08-29 .. 2026-01-30
# Holdings (20): AMG, AMRX, BTU, FLS, FORM, GAP, GMED, HCC, HP, IONS, LUMN, MSGS, NOV, NYT, OII, ORA, PBF, PLXS, RMBS, VIAV
# AMG      0.40
# AMRX    -4.64
# BTU     39.69
# FLS      4.08
# FORM    -5.26
# GAP     11.05
# GMED     3.27
# HCC     36.42
# HP      26.77
# IONS    16.59
# LUMN    -2.04
# MSGS    -2.27
# NOV      9.57
# NYT    -10.17
# OII      6.11
# ORA      4.64
# PBF      1.36
# PLXS    -4.72
# RMBS    -4.77
# VIAV    -1.79
#
# gross = mean of the 20 returns = 0.062149 (6.215%)
# turnover = names replaced / 20 = 7 / 20 = 0.35  ->  cost = 2 x 0.0010 x 0.35 = 0.000700
# net = 0.061449 (6.145%)  ->  on $10,000: $614.49
# Three holdings to check against the CSV by hand: AMG +0.401%, AMRX -4.640%, BTU +39.688%
# Engine's own value for this month: 0.061449 (must equal net above)

# %% [markdown]
# ## Step 8 — the briefing-table generator (the only thing Track 2 ever sees)
# Format per the Briefing-Table Format Specification: 200 rows sorted by ticker; `Ticker | Company | Sector | 1M | 3M | 12M`, trailing total returns in percent (one decimal) as of the stated month-end. The text block is saved to Drive and pasted, unedited, under the frozen prompt.

# %%
# Cell 11 — briefing table as of a month-end (default: the last row of the panel)
def briefing_table(panel, info, as_of=None):
    r = panel if as_of is None else panel.loc[:as_of]
    as_of = r.index[-1].date()
    r1 = r.iloc[-1]
    r3 = (1 + r.iloc[-3:]).prod() - 1
    r12 = (1 + r.iloc[-12:]).prod() - 1
    tbl = pd.DataFrame({"Ticker": r.columns,
                        "Company": info.loc[r.columns, "Company"].values,
                        "Sector": info.loc[r.columns, "Sector"].values,
                        "1M": (100 * r1.values).round(1) + 0.0, "3M": (100 * r3.values).round(1) + 0.0, "12M": (100 * r12.values).round(1) + 0.0})   # + 0.0 turns -0.0 into 0.0
    return tbl.sort_values("Ticker").reset_index(drop=True), as_of

def briefing_text(tbl, as_of):
    lines = [f"BRIEFING TABLE as of {as_of} (month-end). Trailing total returns in percent, dividends reinvested. {len(tbl)} stocks.",
             "Ticker | Company | Sector | 1M | 3M | 12M"]
    for row in tbl.itertuples(index=False):
        lines.append(f"{row.Ticker} | {row.Company} | {row.Sector} | {row[3]:+.1f} | {row[4]:+.1f} | {row[5]:+.1f}")
    return "\n".join(lines)

tbl, as_of = briefing_table(panel, info)                 # August 2026 month-end for the 9/20 commit
text = briefing_text(tbl, as_of)
open(OUT + f"/briefing_table_{as_of}.txt", "w").write(text)
tbl.to_csv(OUT + f"/briefing_table_{as_of}.csv", index=False)
print(text)
# Out:
# BRIEFING TABLE as of 2026-08-31 (month-end). Trailing total returns in percent, dividends reinvested. 200 stocks.
# Ticker | Company | Sector | 1M | 3M | 12M
# ACAD | ACADIA Pharmaceuticals Inc. | Health Care | +11.8 | +33.5 | +11.2
# ACM | AECOM | Industrials | -6.9 | -2.4 | -45.3
# AD | Array Digital Infrastructure, Inc. | Communication Services | +5.2 | -8.7 | +3.9
# ADC | Agree Realty Corporation | Real Estate | -6.8 | -1.5 | +3.6
# AGCO | AGCO Corporation | Industrials | +16.2 | +5.7 | +10.5
# ALK | Alaska Air Group, Inc. | Industrials | -12.9 | -10.2 | -34.2
# AMG | Affiliated Managers Group, Inc. | Financials | +0.4 | +21.6 | +63.8
# AMRX | Amneal Pharmaceuticals, Inc. | Health Care | -4.6 | +32.7 | +82.7
# AOS | A. O. Smith Corporation | Industrials | -1.7 | +4.9 | -15.2
# APPF | AppFolio, Inc. | Information Technology | +30.0 | +45.3 | -15.6
# AROC | Archrock, Inc. | Energy | -11.3 | -5.3 | +30.9
# ASH | Ashland Inc. | Materials | +1.0 | +27.6 | +33.5
# AVA | Avista Corporation | Utilities | -7.0 | -9.2 | +6.7
# AVNT | Avient Corporation | Materials | +21.3 | +25.3 | +21.6
# AVT | Avnet, Inc. | Information Technology | +0.8 | +3.4 | +68.0
# AWR | American States Water Company | Utilities | +4.9 | +16.3 | +23.0
# AYI | Acuity Inc. | Industrials | +1.0 | +8.8 | +1.9
# BAH | Booz Allen Hamilton Holding Corporation | Industrials | +9.3 | -3.0 | -28.4
# BATRK | Atlanta Braves Holdings, Inc. | Communication Services | -2.5 | +0.0 | +10.2
# BCPC | Balchem Corporation | Materials | +5.0 | +12.2 | +9.2
# BIO | Bio-Rad Laboratories, Inc. | Health Care | +18.6 | +23.6 | +29.6
# BKH | Black Hills Corporation | Utilities | +1.6 | -0.6 | +24.5
# BOKF | BOK Financial Corporation | Financials | -3.3 | +6.7 | +24.6
# BRKR | Bruker Corporation | Health Care | -7.7 | -1.4 | +71.6
# BRX | Brixmor Property Group Inc. | Real Estate | -8.3 | -4.5 | +7.8
# BTU | Peabody Energy Corporation | Energy | +39.7 | +10.1 | +72.5
# CAG | Conagra Brands, Inc. | Consumer Staples | +10.4 | +22.0 | -9.6
# CALM | Cal-Maine Foods, Inc. | Consumer Staples | -10.1 | +5.6 | -29.8
# CARG | CarGurus, Inc. | Communication Services | -1.6 | +19.4 | +3.1
# CBSH | Commerce Bancshares, Inc. | Financials | -2.6 | +11.1 | -0.2
# CBT | Cabot Corporation | Materials | -5.5 | -5.0 | +3.9
# CELH | Celsius Holdings, Inc. | Consumer Staples | +7.7 | -5.5 | -50.0
# CENT | Central Garden & Pet Company | Consumer Staples | -0.2 | +11.7 | +18.0
# CHDN | Churchill Downs Incorporated | Consumer Discretionary | +3.8 | +0.3 | -15.3
# CHE | Chemed Corporation | Health Care | -2.4 | +21.8 | +13.9
# CHEF | The Chefs' Warehouse, Inc. | Consumer Staples | -2.5 | +46.9 | +78.1
# CLF | Cleveland-Cliffs Inc. | Materials | +0.3 | -15.1 | +7.4
# CNK | Cinemark Holdings, Inc. | Communication Services | -2.4 | +27.5 | +39.7
# CNX | CNX Resources Corporation | Energy | +1.6 | +8.0 | +24.6
# COTY | Coty Inc. | Consumer Staples | +3.6 | +33.8 | -33.4
# CPB | The Campbell's Company | Consumer Staples | +7.7 | +14.1 | -21.1
# CPK | Chesapeake Utilities Corporation | Utilities | +0.6 | +8.9 | +10.5
# CRK | Comstock Resources, Inc. | Energy | +8.8 | +8.3 | -10.5
# CROX | Crocs, Inc. | Consumer Discretionary | -6.0 | +1.4 | +38.1
# CRUS | Cirrus Logic, Inc. | Information Technology | -15.3 | -35.6 | -4.1
# CTRE | CareTrust REIT, Inc. | Real Estate | -7.1 | -3.7 | +17.7
# CUBE | CubeSmart | Real Estate | -4.2 | +0.6 | +2.6
# CUZ | Cousins Properties Incorporated | Real Estate | -8.1 | +9.3 | +3.2
# CVI | CVR Energy, Inc. | Energy | +17.9 | +26.4 | +38.1
# CVLT | Commvault Systems, Inc. | Information Technology | +16.7 | +15.8 | -26.3
# CWEN | Clearway Energy, Inc. | Utilities | +0.1 | -22.0 | +12.1
# CWT | California Water Service Group | Utilities | +0.4 | +11.5 | +9.5
# DBX | Dropbox, Inc. | Information Technology | +8.1 | +30.9 | +21.1
# DK | Delek US Holdings, Inc. | Energy | +9.9 | +67.6 | +174.3
# DY | Dycom Industries, Inc. | Industrials | -27.4 | -42.9 | +15.3
# EAT | Brinker International, Inc. | Consumer Discretionary | +6.9 | +60.5 | +46.5
# ELF | e.l.f. Beauty, Inc. | Consumer Staples | +31.6 | +94.7 | -12.8
# EMN | Eastman Chemical Company | Materials | +3.6 | -3.4 | +8.1
# EPAM | EPAM Systems, Inc. | Information Technology | +11.6 | +15.0 | -33.2
# EPR | EPR Properties | Real Estate | -4.9 | +4.5 | +15.6
# EPRT | Essential Properties Realty Trust, Inc. | Real Estate | -4.1 | -0.9 | -0.2
# ESI | Element Solutions Inc | Materials | -3.2 | -16.1 | +39.6
# ETSY | Etsy, Inc. | Consumer Discretionary | -0.4 | +19.7 | +53.4
# EXP | Eagle Materials Inc. | Materials | -5.2 | -12.1 | -15.5
# FDS | FactSet Research Systems Inc. | Financials | +19.6 | +28.2 | -14.5
# FIZZ | National Beverage Corp. | Consumer Staples | +0.0 | -5.4 | -16.8
# FLS | Flowserve Corporation | Industrials | +4.1 | +5.0 | +49.3
# FND | Floor & Decor Holdings, Inc. | Consumer Discretionary | -12.7 | -2.2 | -38.6
# FORM | FormFactor, Inc. | Information Technology | -5.3 | -19.2 | +244.7
# FR | First Industrial Realty Trust, Inc. | Real Estate | -6.0 | +0.8 | +21.6
# FRPT | Freshpet, Inc. | Consumer Staples | +17.3 | +35.4 | +25.2
# GAP | The Gap, Inc. | Consumer Discretionary | +11.1 | +6.5 | +4.5
# GATX | GATX Corporation | Industrials | -2.2 | +3.9 | +5.5
# GBCI | Glacier Bancorp, Inc. | Financials | -6.0 | -2.0 | -3.1
# GMED | Globus Medical, Inc. | Health Care | +3.3 | -0.6 | +32.8
# GNTX | Gentex Corporation | Consumer Discretionary | -4.2 | -6.9 | -18.5
# GPK | Graphic Packaging Holding Company | Materials | +4.4 | +0.5 | -48.0
# HAE | Haemonetics Corporation | Health Care | +20.5 | +52.0 | +89.0
# HCC | Warrior Met Coal, Inc. | Materials | +36.4 | +14.6 | +77.7
# HLI | Houlihan Lokey, Inc. | Financials | +6.2 | -5.4 | -32.1
# HP | Helmerich & Payne, Inc. | Energy | +26.8 | +14.9 | +114.7
# HQY | HealthEquity, Inc. | Health Care | -4.0 | +9.7 | +8.1
# HRB | H&R Block, Inc. | Consumer Discretionary | +17.3 | +35.7 | +7.0
# HSIC | Henry Schein, Inc. | Health Care | +4.7 | +17.3 | +29.1
# ICUI | ICU Medical, Inc. | Health Care | +2.6 | +27.7 | +35.5
# IDA | IDACORP, Inc. | Utilities | -4.1 | -2.3 | +11.7
# IDCC | InterDigital, Inc. | Information Technology | +9.9 | +33.2 | +24.4
# INGR | Ingredion Incorporated | Consumer Staples | +4.0 | +2.9 | -17.7
# IONS | Ionis Pharmaceuticals, Inc. | Health Care | +16.6 | -21.1 | +41.6
# IPAR | Interparfums, Inc. | Consumer Staples | -5.7 | +25.4 | +5.7
# IRDM | Iridium Communications Inc. | Communication Services | -0.8 | -9.0 | +93.7
# IRT | Independence Realty Trust, Inc. | Real Estate | -2.7 | +0.8 | -6.8
# ITGR | Integer Holdings Corporation | Health Care | +3.3 | +40.1 | +16.1
# ITRI | Itron, Inc. | Information Technology | -2.7 | +17.6 | -21.1
# KEX | Kirby Corporation | Industrials | +8.2 | +0.9 | +45.9
# KMX | CarMax, Inc. | Consumer Discretionary | +7.1 | +37.4 | +0.0
# KNSL | Kinsale Capital Group, Inc. | Financials | +5.0 | +22.8 | -18.1
# KRG | Kite Realty Group Trust | Real Estate | -9.9 | -4.9 | +19.1
# LEA | Lear Corporation | Consumer Discretionary | -4.3 | -12.2 | +16.6
# LNTH | Lantheus Holdings, Inc. | Health Care | +1.3 | +1.7 | +83.9
# LPX | Louisiana-Pacific Corporation | Materials | -2.3 | -7.3 | -24.7
# LUMN | Lumen Technologies, Inc. | Communication Services | -2.0 | -43.1 | +25.8
# LW | Lamb Weston Holdings, Inc. | Consumer Staples | +4.5 | +27.2 | -2.3
# MAC | The Macerich Company | Real Estate | -8.6 | +5.6 | +32.8
# MAT | Mattel, Inc. | Consumer Discretionary | -0.9 | +0.1 | -18.3
# MGEE | MGE Energy, Inc. | Utilities | -2.3 | +3.6 | -7.1
# MGNI | Magnite, Inc. | Communication Services | +21.7 | +63.9 | -9.5
# MGY | Magnolia Oil & Gas Corporation | Energy | +5.2 | -1.2 | +10.8
# MHK | Mohawk Industries, Inc. | Consumer Discretionary | +4.2 | +19.4 | -3.3
# MKTX | MarketAxess Holdings Inc. | Financials | +0.7 | +25.7 | -9.8
# MMSI | Merit Medical Systems, Inc. | Health Care | +6.6 | +43.8 | +0.1
# MOS | The Mosaic Company | Materials | +9.0 | +0.9 | -25.3
# MSA | MSA Safety Incorporated | Industrials | -1.6 | +13.0 | +10.8
# MSGS | Madison Square Garden Sports Corp. | Communication Services | -2.3 | +2.8 | +94.5
# MTCH | Match Group, Inc. | Communication Services | +3.1 | +13.1 | +11.4
# MTDR | Matador Resources Company | Energy | +17.2 | +9.1 | +18.9
# MTH | Meritage Homes Corporation | Consumer Discretionary | -1.1 | +7.1 | -8.3
# MTN | Vail Resorts, Inc. | Consumer Discretionary | -8.3 | +4.1 | -11.0
# MTRN | Materion Corporation | Materials | +12.0 | +7.4 | +113.8
# MUR | Murphy Oil Corporation | Energy | -7.4 | +1.7 | +52.5
# MUSA | Murphy USA Inc. | Consumer Discretionary | -15.1 | +2.0 | +37.7
# MZTI | The Marzetti Company | Consumer Staples | +5.4 | +1.6 | -36.6
# NEU | NewMarket Corporation | Materials | +5.6 | +16.5 | +10.3
# NJR | New Jersey Resources Corporation | Utilities | -7.9 | -2.6 | +17.2
# NNN | NNN REIT, Inc. | Real Estate | -4.9 | +2.9 | +11.4
# NOV | NOV Inc. | Energy | +9.6 | +7.6 | +64.1
# NOVT | Novanta Inc. | Information Technology | +2.6 | -8.2 | +25.6
# NWE | NorthWestern Energy Group, Inc. | Utilities | +1.6 | -0.2 | +26.5
# NXST | Nexstar Media Group, Inc. | Communication Services | -3.5 | +3.1 | -7.6
# NYT | The New York Times Company | Communication Services | -10.2 | -10.3 | +13.7
# OGE | OGE Energy Corp. | Utilities | -3.6 | -2.5 | +6.0
# OGS | ONE Gas, Inc. | Utilities | +3.0 | +2.8 | +7.1
# OII | Oceaneering International, Inc. | Energy | +6.1 | +35.4 | +112.1
# OMF | OneMain Holdings, Inc. | Financials | +1.4 | +14.8 | +8.4
# ONB | Old National Bancorp | Financials | -4.0 | +7.2 | +14.5
# ORA | Ormat Technologies, Inc. | Utilities | +4.6 | -25.6 | +11.5
# ORI | Old Republic International Corporation | Financials | -3.4 | +13.0 | +13.8
# OSK | Oshkosh Corporation | Industrials | +8.6 | +19.0 | +12.3
# OTTR | Otter Tail Corporation | Utilities | +3.0 | +5.1 | +10.5
# OZK | Bank OZK | Financials | -4.3 | +2.4 | -2.8
# PB | Prosperity Bancshares, Inc. | Financials | -4.4 | +4.6 | +7.1
# PBF | PBF Energy Inc. | Energy | +1.4 | +80.0 | +174.1
# PBH | Prestige Consumer Healthcare Inc. | Health Care | +3.1 | +8.9 | -23.9
# PEGA | Pegasystems Inc. | Information Technology | +20.8 | +3.4 | -31.7
# PLXS | Plexus Corp. | Information Technology | -4.7 | -10.8 | +74.8
# PODD | Insulet Corporation | Health Care | -10.1 | +2.6 | -56.3
# POR | Portland General Electric Company | Utilities | -1.0 | -1.5 | +19.4
# PPC | Pilgrim's Pride Corporation | Consumer Staples | +14.7 | +10.8 | -29.4
# PRI | Primerica, Inc. | Financials | -9.7 | +7.0 | +8.6
# PSMT | PriceSmart, Inc. | Consumer Staples | -12.0 | +0.4 | +59.8
# PTEN | Patterson-UTI Energy, Inc. | Energy | +20.6 | +13.8 | +128.4
# QLYS | Qualys, Inc. | Information Technology | +28.6 | +70.3 | +37.1
# QRVO | Qorvo, Inc. | Information Technology | +6.1 | -7.2 | +5.9
# R | Ryder System, Inc. | Industrials | -4.3 | -2.2 | +32.7
# RDNT | RadNet, Inc. | Health Care | +18.9 | +36.5 | +5.7
# REXR | Rexford Industrial Realty, Inc. | Real Estate | -1.9 | +5.8 | -6.2
# RGEN | Repligen Corporation | Health Care | +28.3 | +46.0 | +48.0
# RHP | Ryman Hospitality Properties, Inc. | Real Estate | -5.2 | +11.1 | +34.5
# RLI | RLI Corp. | Financials | +3.9 | +27.2 | +1.8
# RMBS | Rambus Inc. | Information Technology | -4.8 | -40.4 | +17.5
# RRC | Range Resources Corporation | Energy | +2.9 | +6.4 | +21.8
# RYN | Rayonier Inc. | Real Estate | -5.9 | -0.7 | -13.2
# SAIA | Saia, Inc. | Industrials | +2.2 | -24.8 | +19.8
# SAIC | Science Applications International Corporation | Information Technology | +9.5 | +23.5 | +10.5
# SBRA | Sabra Health Care REIT, Inc. | Real Estate | -2.2 | +4.1 | +13.3
# SFM | Sprouts Farmers Market, Inc. | Consumer Staples | -5.9 | -0.7 | -41.6
# SIGI | Selective Insurance Group, Inc. | Financials | -3.3 | +6.0 | +19.0
# SIRI | Sirius XM Holdings Inc. | Communication Services | -4.0 | -3.7 | +24.6
# SLAB | Silicon Laboratories Inc. | Information Technology | +0.7 | +0.7 | +63.0
# SLGN | Silgan Holdings Inc. | Materials | +3.9 | +11.2 | -9.7
# SM | SM Energy Company | Energy | +14.3 | +21.9 | +34.9
# SNAP | Snap Inc. | Communication Services | +18.3 | -2.8 | -22.3
# SON | Sonoco Products Company | Materials | -1.2 | +14.4 | +21.8
# SPXC | SPX Technologies, Inc. | Industrials | -10.4 | -9.2 | +5.2
# SR | Spire Inc. | Utilities | +2.5 | +0.5 | +11.2
# STAG | STAG Industrial, Inc. | Real Estate | -2.6 | -0.7 | +4.6
# STGW | Stagwell Inc. | Communication Services | +2.7 | +23.8 | +53.9
# SWX | Southwest Gas Holdings, Inc. | Utilities | -0.5 | +3.2 | +13.8
# SXT | Sensient Technologies Corporation | Materials | +9.5 | +18.9 | +20.8
# TAP | Molson Coors Beverage Company | Consumer Staples | -3.2 | +1.8 | -16.9
# TDS | Telephone and Data Systems, Inc. | Communication Services | +0.3 | -13.8 | -15.7
# TDW | Tidewater Inc. | Energy | +24.1 | +26.7 | +54.7
# TKR | The Timken Company | Industrials | -12.2 | -5.6 | +58.1
# TTC | The Toro Company | Industrials | +6.5 | +9.3 | +22.9
# TTD | The Trade Desk, Inc. | Communication Services | -23.9 | -36.4 | -74.9
# TTEK | Tetra Tech, Inc. | Industrials | +9.2 | +31.7 | +0.0
# UGI | UGI Corporation | Utilities | +6.5 | +11.3 | +15.7
# URBN | Urban Outfitters, Inc. | Consumer Discretionary | +8.8 | +11.1 | +20.3
# VIAV | Viavi Solutions Inc. | Information Technology | -1.8 | -25.3 | +221.7
# VLY | Valley National Bancorp | Financials | -4.5 | -0.2 | +35.2
# VNO | Vornado Realty Trust | Real Estate | -5.1 | +10.8 | +0.5
# WAL | Western Alliance Bancorporation | Financials | -2.4 | -1.4 | -10.9
# WEX | WEX Inc. | Financials | +1.9 | +31.5 | +11.2
# WH | Wyndham Hotels & Resorts, Inc. | Consumer Discretionary | -1.6 | -7.7 | -13.1
# WHD | Cactus, Inc. | Energy | +8.4 | +21.7 | +69.4
# WLK | Westlake Corporation | Materials | +7.2 | -12.9 | -12.2
# WLY | John Wiley & Sons, Inc. | Communication Services | +0.4 | +25.4 | +33.9
# WMS | Advanced Drainage Systems, Inc. | Industrials | -2.0 | -2.3 | -5.4
# WYNN | Wynn Resorts, Limited | Consumer Discretionary | -7.9 | -9.6 | -27.3
# ZD | Ziff Davis, Inc. | Communication Services | +3.9 | +22.4 | +44.3

# %% [markdown]
# ## Step 9 — entry 0: Track 1's holdings for September 2026
# September 2026 is row 92, one past the end of the released panel, so its signal window is September 2025 – February 2026 (rows 80–85). The alphabetical list below goes into `monitoring_log.md` entry 0 next to the frozen prompt's picks.

# %%
# Cell 12 — the locked rule's September 2026 portfolio, from data through August 2026
t_next = len(dates)                                        # row 92 = September 2026
hold_next = rule(t_next, rets)
sig_next = S.signal(t_next, rets)
sep = sorted(tickers[i] for i in hold_next)
print(f"Signal window: {dates[t_next-12].date()} .. {dates[t_next-7].date()} (six months)")
print("TRACK 1 September 2026 holdings (alphabetical):")
print(", ".join(sep))
ranked = pd.Series(sig_next, index=tickers).sort_values(ascending=False)
print("\nRanks 18-23 around the boundary (signal = compounded 6-month return):")
print((100 * ranked.iloc[17:23]).round(2).to_string())
open(OUT + "/track1_holdings_2026-09.txt", "w").write(", ".join(sep) + "\n")
print("\nSaved:", sorted(os.listdir(OUT)))
# Out:
# Signal window: 2025-09-30 .. 2026-02-27 (six months)
# TRACK 1 September 2026 holdings (alphabetical):
# AMRX, AROC, BTU, CNX, DY, FLS, FORM, FRPT, GMED, HP, IONS, LUMN, MSGS, MTRN, NOV, OII, PSMT, PTEN, SLAB, VIAV
#
# Ranks 18-23 around the boundary (signal = compounded 6-month return):
# AMRX    44.46
# CNX     43.08
# LUMN    43.06
# PLXS    41.69
# TKR     41.41
# DK      38.38
#
# Saved: ['briefing_table_2026-08-31.csv', 'briefing_table_2026-08-31.txt', 'insample_growth_2026-08-31.png', 'insample_stats_2026-08-31.csv', 'track1_holdings_2026-09.txt']

# %% [markdown]
# ## Before the commit (Sun 9/20)
# 1. Runtime → **Restart session and run all** — no errors, then save.
# 2. Paste Track 1's list (Cell 12) and the frozen prompt's verbatim output into `monitoring_log.md` entry 0.
# 3. Commit to the private repo FINTECH-P2-Example: `strategy_rules.md`, `strategy.py` (Cell 6) with this notebook (File → **Save a copy in GitHub**), `llm_analyst_prompt.md`, `redteam_log.md`, `monitoring_log.md`, and `panel_returns_2026-08-31.csv` (its hash must match the Data Dictionary).
# 4. Copy the seven-character commit hash and quote it in every later deliverable.
